# %% [markdown]
# # Inteligencia Articificial Avanzada
# # Segunda entrega

# %% [markdown]
# ### Ejecutar uno de los 3 modelos y las celdas de informes y gráficos. El que mejor va es Resnet

# %% [markdown]
# ### Primer intento con PyTorch (Esto fue a modo de prueba, es un poco distinto a Keras)

# %%
'''
# Primera versión con todo el dataset.
# Esto es simplemente para ver que corra. No hace ni separación entre entrenamiento y testeo
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# Transformaciones para preprocesar los datos
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Descargar y cargar el dataset CIFAR-10
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)

# Definir un modelo Feedforward simple
class FeedforwardNet(nn.Module):
    def __init__(self):
        super(FeedforwardNet, self).__init__()
        self.fc1 = nn.Linear(32 * 32 * 3, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)

    def forward(self, x):
        x = x.view(-1, 32 * 32 * 3)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Inicializar el modelo
net = FeedforwardNet()

# Definir la función de pérdida y el optimizador
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# Entrenamiento del modelo
for epoch in range(10):
    running_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    print(f'Epoch {epoch + 1}, Loss: {running_loss / len(trainloader)}')

print('Entrenamiento finalizado!')
'''
# Out:
# Files already downloaded and verified
# Epoch 1, Loss: 2.051612351861451
# Epoch 2, Loss: 1.7603317186655596
# Epoch 3, Loss: 1.6381577828046305
# Epoch 4, Loss: 1.5631127191321623
# Epoch 5, Loss: 1.5032563814726632
# Epoch 6, Loss: 1.450783946020219
# Epoch 7, Loss: 1.4035567133627889
# Epoch 8, Loss: 1.3596471381919157
# Epoch 9, Loss: 1.317712705001197
# Epoch 10, Loss: 1.2800419948747397
# Entrenamiento finalizado!

# %% [markdown]
# ### Modelo 1 - Feed Fordward

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# Transformaciones para preprocesar los datos
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Descargar y cargar el dataset CIFAR-10
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Definir una lista de las clases que queremos mantener: auto, barco y camión
classes_to_keep = ['automobile', 'ship', 'truck']

# Crear un nuevo dataset solo con las clases seleccionadas
filtered_trainset = [(img, label) for img, label in trainset if trainset.classes[label] in classes_to_keep]

# Mapear las etiquetas a índices (0, 1, 2)
class_to_idx = {cls: idx for idx, cls in enumerate(classes_to_keep)}
filtered_trainset = [(img, class_to_idx[trainset.classes[label]]) for img, label in filtered_trainset]

# Divide el conjunto de datos en entrenamiento (75%%) y validación (25%)
trainset, valset = train_test_split(filtered_trainset, test_size=0.25, random_state=42)

# Crea DataLoaders separados para entrenamiento y validación
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=False)

# Definir un modelo Feedforward simple
class FeedforwardNet(nn.Module):
    def __init__(self):
        super(FeedforwardNet, self).__init__()
        self.fc1 = nn.Linear(32 * 32 * 3, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, len(classes_to_keep))
        # Salida igual al número de clases seleccionadas

    def forward(self, x):
        x = x.view(-1, 32 * 32 * 3)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Inicializar el modelo
net = FeedforwardNet()

# Definir la función de pérdida y el optimizador
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

best_val_loss = float('inf')  # Inicializa la mejor pérdida en validación con un valor alto
early_stop_counter = 0  # Inicializa un contador para el early stopping

# Métricas de entrenamiento y validación
train_loss_history = []
train_accuracy_history = []
val_loss_history = []
val_accuracy_history = []

# Función para calcular las predicciones en el conjunto de validación
def get_predictions(net, dataloader):
    all_labels = []
    all_preds = []
    net.eval()
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    return np.array(all_labels), np.array(all_preds)

# Entrenamiento del modelo
for epoch in range(20):
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    train_loss_history.append(running_loss / len(trainloader))
    train_accuracy_history.append(accuracy)

    # Validación
    val_loss = 0.0
    correct = 0
    total = 0
    net.eval()
    with torch.no_grad():
        for data in valloader:
            inputs, labels = data
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    val_loss_history.append(val_loss / len(valloader))
    val_accuracy_history.append(accuracy)

    # Comprueba si la pérdida en validación mejoró
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stop_counter = 0
    else:
        early_stop_counter += 1

    # Si no hubo mejoras en n épocas, para de entrenar
    n = 3
    if early_stop_counter >= n:
        print('Early stopping. Fin del entrenamiento.')
        break

    print(f'Epoch {epoch + 1}, Loss: {running_loss / len(trainloader):.4f}, Accuracy: {accuracy:.2f}')

print('Finished Training')

# Imprimir las métricas finales
print(f'Final Training Loss: {train_loss_history[-1]:.4f}, Final Training Accuracy: {train_accuracy_history[-1]:.2f}')
print(f'Final Validation Loss: {val_loss_history[-1]:.4f}, Final Validation Accuracy: {val_accuracy_history[-1]:.2f}')

# Obtener las predicciones en el conjunto de validación
val_true_labels, val_predictions = get_predictions(net, valloader)

# Calcular la matriz de confusión para el conjunto de validación
val_confusion_matrix = confusion_matrix(val_true_labels, val_predictions)

# Calcular la matriz de confusión para el conjunto de entrenamiento
train_true_labels, train_predictions = get_predictions(net, trainloader)
train_confusion_matrix = confusion_matrix(train_true_labels, train_predictions)

# Imprimir las matrices de confusión
print("Matriz de Confusión para el Conjunto de Entrenamiento:")
print(train_confusion_matrix)
print("\nMatriz de Confusión para el Conjunto de Validación:")
print(val_confusion_matrix)
# Out:
# Files already downloaded and verified
# Epoch 1, Loss: 1.0188, Accuracy: 57.23
# Epoch 2, Loss: 0.8750, Accuracy: 60.88
# Epoch 3, Loss: 0.8078, Accuracy: 64.11
# Epoch 4, Loss: 0.7659, Accuracy: 66.40
# Epoch 5, Loss: 0.7329, Accuracy: 68.93
# Epoch 6, Loss: 0.7036, Accuracy: 69.28
# Epoch 7, Loss: 0.6746, Accuracy: 70.37
# Epoch 8, Loss: 0.6468, Accuracy: 71.12
# Epoch 9, Loss: 0.6224, Accuracy: 71.73
# Epoch 10, Loss: 0.5983, Accuracy: 72.29
# Epoch 11, Loss: 0.5765, Accuracy: 72.11
# Epoch 12, Loss: 0.5564, Accuracy: 73.55
# Epoch 13, Loss: 0.5345, Accuracy: 73.60
# Epoch 14, Loss: 0.5125, Accuracy: 73.95
# Epoch 15, Loss: 0.4960, Accuracy: 74.40
# Epoch 16, Loss: 0.4721, Accuracy: 74.48
# Epoch 17, Loss: 0.4545, Accuracy: 74.40
# Epoch 18, Loss: 0.4327, Accuracy: 73.44
# Epoch 19, Loss: 0.4147, Accuracy: 75.12
# Epoch 20, Loss: 0.3957, Accuracy: 75.23
# Finished Training
# Final Training Loss: 0.3957, Final Training Accuracy: 85.72
# Final Validation Loss: 0.6138, Final Validation Accuracy: 75.23
# Matriz de Confusión para el Conjunto de Entrenamiento:
# [[3177  120  379]
#  [ 192 3408  231]
#  [ 379   90 3274]]
#
# Matriz de Confusión para el Conjunto de Validación:
# [[955 102 267]
#  [119 942 108]
#  [244  89 924]]

# %% [markdown]
# ### Modelo 2 - CNN (En la primera entrega usamos Keras)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

# Transformaciones para preprocesar los datos
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Descargar y cargar el dataset CIFAR-10
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Definir una lista de las clases que queremos mantener: auto, barco y camión
classes_to_keep = ['automobile', 'ship', 'truck']

# Crear un nuevo dataset solo con las clases seleccionadas
filtered_trainset = [(img, label) for img, label in trainset if trainset.classes[label] in classes_to_keep]

# Mapear las etiquetas a índices (0, 1, 2)
class_to_idx = {cls: idx for idx, cls in enumerate(classes_to_keep)}
filtered_trainset = [(img, class_to_idx[trainset.classes[label]]) for img, label in filtered_trainset]

# Divide el conjunto de datos en entrenamiento (75%) y validación (25%)
trainset, valset = train_test_split(filtered_trainset, test_size=0.25, random_state=42)

# Crea DataLoaders separados para entrenamiento y validación
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=False)

# Definir una CNN
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(64 * 16 * 16, 128)
        self.fc2 = nn.Linear(128, len(classes_to_keep))

    def forward(self, x):
        x = self.pool(torch.relu(self.conv1(x)))
        x = x.view(-1, 64 * 16 * 16)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Inicializar el modelo CNN
net = CNN()

# Definir la función de pérdida y el optimizador
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

best_val_loss = float('inf')  # Inicializa la mejor pérdida en validación con un valor alto
early_stop_counter = 0  # Inicializa un contador para el early stopping

# Métricas de entrenamiento y validación
train_loss_history = []
train_accuracy_history = []
val_loss_history = []
val_accuracy_history = []

# Función para calcular las predicciones en el conjunto de validación
def get_predictions(net, dataloader):
    all_labels = []
    all_preds = []
    net.eval()
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    return np.array(all_labels), np.array(all_preds)

# Entrenamiento del modelo
for epoch in range(20):
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    train_loss_history.append(running_loss / len(trainloader))
    train_accuracy_history.append(accuracy)

    # Validación
    val_loss = 0.0
    correct = 0
    total = 0
    net.eval()
    with torch.no_grad():
        for data in valloader:
            inputs, labels = data
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    val_loss_history.append(val_loss / len(valloader))
    val_accuracy_history.append(accuracy)

    # Comprueba si la pérdida en validación mejoró
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stop_counter = 0
    else:
        early_stop_counter += 1

    # Si no hubo mejoras en n épocas, para de entrenar
    n = 3
    if early_stop_counter >= n:
        print('Early stopping. Fin del entrenamiento.')
        break

    print(f'Epoch {epoch + 1}, Loss: {running_loss / len(trainloader):.4f}, Accuracy: {accuracy:.2f}')

print('Finished Training')

# Imprimir las métricas finales
print(f'Final Training Loss: {train_loss_history[-1]:.4f}, Final Training Accuracy: {train_accuracy_history[-1]:.2f}')
print(f'Final Validation Loss: {val_loss_history[-1]:.4f}, Final Validation Accuracy: {val_accuracy_history[-1]:.2f}')

# Obtener las predicciones en el conjunto de validación
val_true_labels, val_predictions = get_predictions(net, valloader)

# Calcular la matriz de confusión para el conjunto de validación
val_confusion_matrix = confusion_matrix(val_true_labels, val_predictions)

# Calcular la matriz de confusión para el conjunto de entrenamiento
train_true_labels, train_predictions = get_predictions(net, trainloader)
train_confusion_matrix = confusion_matrix(train_true_labels, train_predictions)

# Imprimir las matrices de confusión
print("Matriz de Confusión para el Conjunto de Entrenamiento:")
print(train_confusion_matrix)
print("\nMatriz de Confusión para el Conjunto de Validación:")
print(val_confusion_matrix)
# Out:
# Files already downloaded and verified
# Epoch 1, Loss: 0.8928, Accuracy: 64.32
# Epoch 2, Loss: 0.7604, Accuracy: 67.28
# Epoch 3, Loss: 0.7009, Accuracy: 70.45
# Epoch 4, Loss: 0.6445, Accuracy: 72.45
# Epoch 5, Loss: 0.6039, Accuracy: 74.48
# Epoch 6, Loss: 0.5682, Accuracy: 74.99
# Epoch 7, Loss: 0.5366, Accuracy: 75.84
# Epoch 8, Loss: 0.5180, Accuracy: 77.28
# Epoch 9, Loss: 0.4819, Accuracy: 78.21
# Epoch 10, Loss: 0.4597, Accuracy: 79.52
# Epoch 11, Loss: 0.4456, Accuracy: 79.81
# Epoch 12, Loss: 0.4312, Accuracy: 80.03
# Epoch 13, Loss: 0.4186, Accuracy: 80.88
# Epoch 14, Loss: 0.3934, Accuracy: 80.77
# Epoch 15, Loss: 0.3852, Accuracy: 81.44
# Epoch 16, Loss: 0.3669, Accuracy: 80.32
# Epoch 17, Loss: 0.3551, Accuracy: 82.24
# Epoch 18, Loss: 0.3468, Accuracy: 81.89
# Epoch 19, Loss: 0.3304, Accuracy: 81.79
# Early stopping. Fin del entrenamiento.
# Finished Training
# Final Training Loss: 0.3202, Final Training Accuracy: 88.04
# Final Validation Loss: 0.4944, Final Validation Accuracy: 80.51
# Matriz de Confusión para el Conjunto de Entrenamiento:
# [[3435  158   83]
#  [ 201 3576   54]
#  [ 813  217 2713]]
#
# Matriz de Confusión para el Conjunto de Validación:
# [[1158   95   71]
#  [  81 1053   35]
#  [ 355   94  808]]

# %% [markdown]
# ### Modelo 3 - ResNet - Este guarda en el drive. Después se puede ejecutar la celda de abajo

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

# Transformaciones para preprocesar los datos
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Descargar y cargar el dataset CIFAR-10
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Definir una lista de las clases que queremos mantener: auto, barco y camión
classes_to_keep = ['automobile', 'ship', 'truck']

# Crear un nuevo dataset solo con las clases seleccionadas
filtered_trainset = [(img, label) for img, label in trainset if trainset.classes[label] in classes_to_keep]

# Mapear las etiquetas a índices (0, 1, 2)
class_to_idx = {cls: idx for idx, cls in enumerate(classes_to_keep)}
filtered_trainset = [(img, class_to_idx[trainset.classes[label]]) for img, label in filtered_trainset]

# Divide el conjunto de datos en entrenamiento (75%) y validación (25%)
trainset, valset = train_test_split(filtered_trainset, test_size=0.25, random_state=42)

# Crea DataLoaders separados para entrenamiento y validación
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=False)

# Definir la arquitectura ResNet-18 preentrenada
import torchvision.models as models

# Cargar la arquitectura ResNet-18 preentrenada
net = models.resnet18(pretrained=True)

# Modificar la capa de salida para tener 3 clases en lugar de 1000 (que es la cantidad original de clases en ImageNet)
num_features = net.fc.in_features
net.fc = nn.Linear(num_features, len(classes_to_keep))

# Definir la función de pérdida y el optimizador
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

best_val_loss = float('inf')  # Inicializa la mejor pérdida en validación con un valor alto
early_stop_counter = 0  # Inicializa un contador para el early stopping

# Métricas de entrenamiento y validación
train_loss_history = []
train_accuracy_history = []
val_loss_history = []
val_accuracy_history = []

# Función para calcular las predicciones en el conjunto de validación
def get_predictions(net, dataloader):
    all_labels = []
    all_preds = []
    net.eval()
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    return np.array(all_labels), np.array(all_preds)

# Entrenamiento del modelo
for epoch in range(20):
    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data

        optimizer.zero_grad()

        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    train_loss_history.append(running_loss / len(trainloader))
    train_accuracy_history.append(accuracy)

    # Validación
    val_loss = 0.0
    correct = 0
    total = 0
    net.eval()
    with torch.no_grad():
        for data in valloader:
            inputs, labels = data
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    val_loss_history.append(val_loss / len(valloader))
    val_accuracy_history.append(accuracy)

    # Comprueba si la pérdida en validación mejoró
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stop_counter = 0
    else:
        early_stop_counter += 1

    # Si no hubo mejoras en n épocas, para de entrenar
    n = 3
    if early_stop_counter >= n:
        print('Early stopping. Fin del entrenamiento.')
        break

    print(f'Epoch {epoch + 1}, Loss: {running_loss / len(trainloader):.4f}, Accuracy: {accuracy:.2f}')

print('Finished Training')

# Imprimir las métricas finales
print(f'Final Training Loss: {train_loss_history[-1]:.4f}, Final Training Accuracy: {train_accuracy_history[-1]:.2f}')
print(f'Final Validation Loss: {val_loss_history[-1]:.4f}, Final Validation Accuracy: {val_accuracy_history[-1]:.2f}')

# Obtener las predicciones en el conjunto de validación
val_true_labels, val_predictions = get_predictions(net, valloader)

# Calcular la matriz de confusión para el conjunto de validación
val_confusion_matrix = confusion_matrix(val_true_labels, val_predictions)

# Calcular la matriz de confusión para el conjunto de entrenamiento
train_true_labels, train_predictions = get_predictions(net, trainloader)
train_confusion_matrix = confusion_matrix(train_true_labels, train_predictions)

# Imprimir las matrices de confusión
print("Matriz de Confusión para el Conjunto de Entrenamiento:")
print(train_confusion_matrix)
print("\nMatriz de Confusión para el Conjunto de Validación:")
print(val_confusion_matrix)
torch.save(net.state_dict(), '/content/drive/MyDrive/resnet_entrenado.pth')

import pickle

# Crea un diccionario que contenga todas las variables
# Guardo todo por que al cargar después lo puedo necesitar
variables = {
    'trainloader': trainloader,
    'valloader': valloader,
    'net': net,
    'optimizer': optimizer,
    'train_loss_history': train_loss_history,
    'train_accuracy_history': train_accuracy_history,
    'val_loss_history': val_loss_history,
    'val_accuracy_history': val_accuracy_history,
    'best_val_loss': best_val_loss,
    'early_stop_counter': early_stop_counter,
    'train_confusion_matrix': train_confusion_matrix,
    'val_confusion_matrix': val_confusion_matrix
}

# Guarda el diccionario en un archivo pickle
with open('/content/drive/MyDrive/resnet_entrenado_variables.pkl', 'wb') as file:
    pickle.dump(variables, file)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 210MB/s]
# Epoch 1, Loss: 0.6004, Accuracy: 86.51
# Epoch 2, Loss: 0.3071, Accuracy: 85.41
# Epoch 3, Loss: 0.2255, Accuracy: 88.32
# Epoch 4, Loss: 0.1734, Accuracy: 88.40
# Epoch 5, Loss: 0.1254, Accuracy: 91.25
# Epoch 6, Loss: 0.0712, Accuracy: 91.79
# Epoch 7, Loss: 0.0552, Accuracy: 91.20
# Early stopping. Fin del entrenamiento.
# Finished Training
# Final Training Loss: 0.0384, Final Training Accuracy: 98.58
# Final Validation Loss: 0.3510, Final Validation Accuracy: 90.75
# Matriz de Confusión para el Conjunto de Entrenamiento:
# [[3670    4    2]
#  [  12 3814    5]
#  [  76   37 3630]]
#
# Matriz de Confusión para el Conjunto de Validación:
# [[1242   41   41]
#  [  37 1111   21]
#  [ 153   54 1050]]

# %% [markdown]
# ### Modelo 3 - ResNet - Carga de modelo previamente guardado arriba

# %%
import torch
import torch.nn as nn
import torchvision
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

import pickle

# Carga el diccionario desde el archivo pickle
with open('/content/drive/MyDrive/resnet_entrenado_variables.pkl', 'rb') as file:
    variables = pickle.load(file)

# Ahora, puedes acceder a tus variables como lo hacías antes
trainloader = variables['trainloader']
valloader = variables['valloader']
net = variables['net']
optimizer = variables['optimizer']
train_loss_history = variables['train_loss_history']
train_accuracy_history = variables['train_accuracy_history']
val_loss_history = variables['val_loss_history']
val_accuracy_history = variables['val_accuracy_history']
best_val_loss = variables['best_val_loss']
early_stop_counter = variables['early_stop_counter']
train_confusion_matrix = variables['train_confusion_matrix']
val_confusion_matrix = variables['val_confusion_matrix']


# Definir las transformaciones para preprocesar los datos
transform = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# Descargar y cargar el conjunto de datos CIFAR-10
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)

# Definir una lista de las clases que queremos mantener: auto, barco y camión
classes_to_keep = ['automobile', 'ship', 'truck']

# Crear un nuevo conjunto de datos solo con las clases seleccionadas
filtered_trainset = [(img, label) for img, label in trainset if trainset.classes[label] in classes_to_keep]

# Mapear las etiquetas a índices (0, 1, 2)
class_to_idx = {cls: idx for idx, cls in enumerate(classes_to_keep)}
filtered_trainset = [(img, class_to_idx[trainset.classes[label]]) for img, label in filtered_trainset]

# Dividir el conjunto de datos en entrenamiento (75%) y validación (25%)
trainset, valset = train_test_split(filtered_trainset, test_size=0.25, random_state=42)
# Misma división que antes

# Crear DataLoaders separados para entrenamiento y validación
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=False)

# Crear un modelo ResNet-18 sin pesos preentrenados
net = torchvision.models.resnet18(pretrained=False)
net.fc = nn.Linear(net.fc.in_features, len(classes_to_keep))

# Cargar el modelo entrenado
net.load_state_dict(torch.load('/content/drive/MyDrive/resnet_entrenado.pth'))
net.eval()  # Establecer el modelo en modo de evaluación

# Función para calcular las predicciones en el conjunto de validación
def get_predictions(net, dataloader):
    all_labels = []
    all_preds = []
    net.eval()
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data
            outputs = net(inputs)
            _, predicted = torch.max(outputs.data, 1)
            all_labels.extend(labels.cpu().numpy())
            all_preds.extend(predicted.cpu().numpy())
    return np.array(all_labels), np.array(all_preds)

# Obtener las predicciones en el conjunto de validación
val_true_labels, val_predictions = get_predictions(net, valloader)

# Calcular la matriz de confusión para el conjunto de validación
val_confusion_matrix = confusion_matrix(val_true_labels, val_predictions)

# Calcular la matriz de confusión para el conjunto de entrenamiento
train_true_labels, train_predictions = get_predictions(net, trainloader)
train_confusion_matrix = confusion_matrix(train_true_labels, train_predictions)

# Imprimir las matrices de confusión
print("Matriz de Confusión para el Conjunto de Entrenamiento:")
print(train_confusion_matrix)
print("\nMatriz de Confusión para el Conjunto de Validación:")
print(val_confusion_matrix)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Files already downloaded and verified
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Matriz de Confusión para el Conjunto de Entrenamiento:
# [[3670    4    2]
#  [  12 3814    5]
#  [  76   37 3630]]
#
# Matriz de Confusión para el Conjunto de Validación:
# [[1242   41   41]
#  [  37 1111   21]
#  [ 153   54 1050]]

# %% [markdown]
# ### Informes

# %%
# Número de épocas durante el entrenamiento
num_epochs = len(train_loss_history)
class_to_idx = {"auto": 0, "barco": 1, "camión": 2}
# Definir un diccionario que mapea los índices a los nombres de las clases
idx_to_class = {v: k for k, v in class_to_idx.items()}

# Imprimir métricas de entrenamiento
print("Métricas de Entrenamiento:")
print("Época\tPérdida Entrenamiento\tPrecisión Entrenamiento")
for epoch in range(num_epochs):
    print(f"{epoch+1}\t{train_loss_history[epoch]}\t\t\t{train_accuracy_history[epoch]}")

# Imprimir métricas de validación
print("\nMétricas de Validación:")
print("Época\tPérdida Validación\tPrecisión Validación")
for epoch in range(num_epochs):
    print(f"{epoch+1}\t{val_loss_history[epoch]}\t\t\t{val_accuracy_history[epoch]}")
# Out:
# Métricas de Entrenamiento:
# Época	Pérdida Entrenamiento	Precisión Entrenamiento
# 1	0.600449469617822			74.54222222222222
# 2	0.30709909546104347			88.35555555555555
# 3	0.22547154018486087			91.73333333333333
# 4	0.17341973194429142			93.62666666666667
# 5	0.125429897071709			95.30666666666667
# 6	0.07115544017340819			97.35111111111111
# 7	0.05515831886176867			97.94666666666667
# 8	0.0383505107059715			98.57777777777778
#
# Métricas de Validación:
# Época	Pérdida Validación	Precisión Validación
# 1	0.3629034363617331			86.50666666666666
# 2	0.3994759154521813			85.41333333333333
# 3	0.31701136809789526			88.32
# 4	0.30874921772944725			88.4
# 5	0.2639307185881219			91.25333333333333
# 6	0.26418833766069455			91.78666666666666
# 7	0.30155997230844983			91.2
# 8	0.35104705570107797			90.74666666666667

# %%
from prettytable import PrettyTable

# Obtener los primeros 100 nombres de las clases reales y predichas para el conjunto de entrenamiento
num_results_to_print = 100
train_true_class_names_subset = [idx_to_class[i] for i in train_true_labels[:num_results_to_print]]
train_pred_class_names_subset = [idx_to_class[i] for i in train_predictions[:num_results_to_print]]
train_true_labels_subset = train_true_labels[:num_results_to_print]
train_predictions_subset = train_predictions[:num_results_to_print]

# Crear una tabla para mostrar los resultados
table = PrettyTable(["Índice", "True Value", "True Class", "Predicted", "Predicted Class"])

# Llenar la tabla con los primeros 100 resultados
for i in range(num_results_to_print):
    table.add_row([i, train_true_labels_subset[i], train_true_class_names_subset[i],
                   train_predictions_subset[i], train_pred_class_names_subset[i]])

# Imprimir la tabla
print("Primeros 100 Resultados para el Conjunto de Entrenamiento:")
print(table)
# Out:
# Primeros 100 Resultados para el Conjunto de Entrenamiento:
# +--------+------------+------------+-----------+-----------------+
# | Índice | True Value | True Class | Predicted | Predicted Class |
# +--------+------------+------------+-----------+-----------------+
# |   0    |     1      |   barco    |     1     |      barco      |
# |   1    |     2      |   camión   |     2     |      camión     |
# |   2    |     0      |    auto    |     0     |       auto      |
# |   3    |     0      |    auto    |     0     |       auto      |
# |   4    |     2      |   camión   |     2     |      camión     |
# |   5    |     2      |   camión   |     2     |      camión     |
# |   6    |     2      |   camión   |     2     |      camión     |
# |   7    |     1      |   barco    |     1     |      barco      |
# |   8    |     2      |   camión   |     2     |      camión     |
# |   9    |     1      |   barco    |     1     |      barco      |
# |   10   |     2      |   camión   |     2     |      camión     |
# |   11   |     2      |   camión   |     2     |      camión     |
# |   12   |     2      |   camión   |     2     |      camión     |
# |   13   |     0      |    auto    |     0     |       auto      |
# |   14   |     2      |   camión   |     2     |      camión     |
# |   15   |     0      |    auto    |     0     |       auto      |
# |   16   |     2      |   camión   |     2     |      camión     |
# |   17   |     2      |   camión   |     2     |      camión     |
# |   18   |     2      |   camión   |     2     |      camión     |
# |   19   |     0      |    auto    |     0     |       auto      |
# |   20   |     0      |    auto    |     0     |       auto      |
# |   21   |     1      |   barco    |     1     |      barco      |
# |   22   |     1      |   barco    |     1     |      barco      |
# |   23   |     1      |   barco    |     1     |      barco      |
# |   24   |     0      |    auto    |     0     |       auto      |
# |   25   |     2      |   camión   |     2     |      camión     |
# |   26   |     2      |   camión   |     2     |      camión     |
# |   27   |     0      |    auto    |     0     |       auto      |
# |   28   |     2      |   camión   |     2     |      camión     |
# |   29   |     0      |    auto    |     0     |       auto      |
# |   30   |     0      |    auto    |     0     |       auto      |
# |   31   |     0      |    auto    |     0     |       auto      |
# |   32   |     2      |   camión   |     2     |      camión     |
# |   33   |     0      |    auto    |     0     |       auto      |
# |   34   |     1      |   barco    |     1     |      barco      |
# |   35   |     2      |   camión   |     2     |      camión     |
# |   36   |     0      |    auto    |     0     |       auto      |
# |   37   |     1      |   barco    |     1     |      barco      |
# |   38   |     2      |   camión   |     2     |      camión     |
# |   39   |     0      |    auto    |     0     |       auto      |
# |   40   |     2      |   camión   |     2     |      camión     |
# |   41   |     0      |    auto    |     0     |       auto      |
# |   42   |     2      |   camión   |     2     |      camión     |
# |   43   |     0      |    auto    |     0     |       auto      |
# |   44   |     1      |   barco    |     1     |      barco      |
# |   45   |     1      |   barco    |     1     |      barco      |
# |   46   |     0      |    auto    |     0     |       auto      |
# |   47   |     2      |   camión   |     2     |      camión     |
# |   48   |     2      |   camión   |     2     |      camión     |
# |   49   |     0      |    auto    |     0     |       auto      |
# |   50   |     0      |    auto    |     0     |       auto      |
# |   51   |     0      |    auto    |     0     |       auto      |
# |   52   |     1      |   barco    |     1     |      barco      |
# |   53   |     2      |   camión   |     2     |      camión     |
# |   54   |     0      |    auto    |     0     |       auto      |
# |   55   |     2      |   camión   |     2     |      camión     |
# |   56   |     1      |   barco    |     1     |      barco      |
# |   57   |     2      |   camión   |     0     |       auto      |
# |   58   |     2      |   camión   |     2     |      camión     |
# |   59   |     2      |   camión   |     2     |      camión     |
# |   60   |     1      |   barco    |     1     |      barco      |
# |   61   |     2      |   camión   |     2     |      camión     |
# |   62   |     0      |    auto    |     0     |       auto      |
# |   63   |     2      |   camión   |     2     |      camión     |
# |   64   |     1      |   barco    |     1     |      barco      |
# |   65   |     1      |   barco    |     1     |      barco      |
# |   66   |     0      |    auto    |     0     |       auto      |
# |   67   |     0      |    auto    |     0     |       auto      |
# |   68   |     0      |    auto    |     0     |       auto      |
# |   69   |     0      |    auto    |     0     |       auto      |
# |   70   |     2      |   camión   |     2     |      camión     |
# |   71   |     1      |   barco    |     1     |      barco      |
# |   72   |     1      |   barco    |     1     |      barco      |
# |   73   |     1      |   barco    |     1     |      barco      |
# |   74   |     1      |   barco    |     1     |      barco      |
# |   75   |     1      |   barco    |     1     |      barco      |
# |   76   |     2      |   camión   |     2     |      camión     |
# |   77   |     0      |    auto    |     0     |       auto      |
# |   78   |     1      |   barco    |     1     |      barco      |
# |   79   |     1      |   barco    |     1     |      barco      |
# |   80   |     2      |   camión   |     2     |      camión     |
# |   81   |     2      |   camión   |     2     |      camión     |
# |   82   |     1      |   barco    |     1     |      barco      |
# |   83   |     1      |   barco    |     1     |      barco      |
# |   84   |     2      |   camión   |     2     |      camión     |
# |   85   |     2      |   camión   |     2     |      camión     |
# |   86   |     0      |    auto    |     0     |       auto      |
# |   87   |     2      |   camión   |     2     |      camión     |
# |   88   |     2      |   camión   |     2     |      camión     |
# |   89   |     1      |   barco    |     1     |      barco      |
# |   90   |     1      |   barco    |     1     |      barco      |
# |   91   |     0      |    auto    |     0     |       auto      |
# |   92   |     0      |    auto    |     0     |       auto      |
# |   93   |     0      |    auto    |     0     |       auto      |
# |   94   |     2      |   camión   |     2     |      camión     |
# |   95   |     0      |    auto    |     0     |       auto      |
# |   96   |     0      |    auto    |     0     |       auto      |
# |   97   |     2      |   camión   |     2     |      camión     |
# |   98   |     0      |    auto    |     0     |       auto      |
# |   99   |     2      |   camión   |     2     |      camión     |
# +--------+------------+------------+-----------+-----------------+

# %%
from prettytable import PrettyTable

# Obtener los primeros 100 nombres de las clases reales y predichas para el conjunto de validación
num_results_to_print = 100
val_true_class_names_subset = [idx_to_class[i] for i in val_true_labels[:num_results_to_print]]
val_pred_class_names_subset = [idx_to_class[i] for i in val_predictions[:num_results_to_print]]
val_true_labels_subset = val_true_labels[:num_results_to_print]
val_predictions_subset = val_predictions[:num_results_to_print]

# Crear una tabla para mostrar los resultados
table = PrettyTable(["Índice", "True Value", "True Class", "Predicted", "Predicted Class"])

# Llenar la tabla con los primeros 100 resultados
for i in range(num_results_to_print):
    table.add_row([i, val_true_labels_subset[i], val_true_class_names_subset[i],
                   val_predictions_subset[i], val_pred_class_names_subset[i]])

# Imprimir la tabla
print("Primeros 100 Resultados para el Conjunto de Validación:")
print(table)
# Out:
# Primeros 100 Resultados para el Conjunto de Validación:
# +--------+------------+------------+-----------+-----------------+
# | Índice | True Value | True Class | Predicted | Predicted Class |
# +--------+------------+------------+-----------+-----------------+
# |   0    |     2      |   camión   |     2     |      camión     |
# |   1    |     0      |    auto    |     0     |       auto      |
# |   2    |     0      |    auto    |     0     |       auto      |
# |   3    |     1      |   barco    |     1     |      barco      |
# |   4    |     0      |    auto    |     0     |       auto      |
# |   5    |     1      |   barco    |     1     |      barco      |
# |   6    |     1      |   barco    |     1     |      barco      |
# |   7    |     1      |   barco    |     1     |      barco      |
# |   8    |     2      |   camión   |     1     |      barco      |
# |   9    |     2      |   camión   |     2     |      camión     |
# |   10   |     2      |   camión   |     2     |      camión     |
# |   11   |     0      |    auto    |     0     |       auto      |
# |   12   |     2      |   camión   |     2     |      camión     |
# |   13   |     1      |   barco    |     1     |      barco      |
# |   14   |     0      |    auto    |     0     |       auto      |
# |   15   |     1      |   barco    |     1     |      barco      |
# |   16   |     0      |    auto    |     0     |       auto      |
# |   17   |     2      |   camión   |     0     |       auto      |
# |   18   |     2      |   camión   |     2     |      camión     |
# |   19   |     0      |    auto    |     0     |       auto      |
# |   20   |     0      |    auto    |     0     |       auto      |
# |   21   |     0      |    auto    |     0     |       auto      |
# |   22   |     0      |    auto    |     0     |       auto      |
# |   23   |     0      |    auto    |     0     |       auto      |
# |   24   |     1      |   barco    |     1     |      barco      |
# |   25   |     2      |   camión   |     2     |      camión     |
# |   26   |     1      |   barco    |     1     |      barco      |
# |   27   |     1      |   barco    |     2     |      camión     |
# |   28   |     1      |   barco    |     1     |      barco      |
# |   29   |     0      |    auto    |     0     |       auto      |
# |   30   |     0      |    auto    |     0     |       auto      |
# |   31   |     1      |   barco    |     1     |      barco      |
# |   32   |     0      |    auto    |     0     |       auto      |
# |   33   |     1      |   barco    |     1     |      barco      |
# |   34   |     0      |    auto    |     0     |       auto      |
# |   35   |     0      |    auto    |     0     |       auto      |
# |   36   |     0      |    auto    |     0     |       auto      |
# |   37   |     2      |   camión   |     2     |      camión     |
# |   38   |     0      |    auto    |     0     |       auto      |
# |   39   |     1      |   barco    |     1     |      barco      |
# |   40   |     1      |   barco    |     0     |       auto      |
# |   41   |     0      |    auto    |     0     |       auto      |
# |   42   |     2      |   camión   |     2     |      camión     |
# |   43   |     2      |   camión   |     2     |      camión     |
# |   44   |     2      |   camión   |     2     |      camión     |
# |   45   |     1      |   barco    |     1     |      barco      |
# |   46   |     1      |   barco    |     1     |      barco      |
# |   47   |     2      |   camión   |     2     |      camión     |
# |   48   |     0      |    auto    |     0     |       auto      |
# |   49   |     0      |    auto    |     0     |       auto      |
# |   50   |     1      |   barco    |     1     |      barco      |
# |   51   |     2      |   camión   |     2     |      camión     |
# |   52   |     0      |    auto    |     0     |       auto      |
# |   53   |     1      |   barco    |     1     |      barco      |
# |   54   |     0      |    auto    |     0     |       auto      |
# |   55   |     0      |    auto    |     1     |      barco      |
# |   56   |     2      |   camión   |     2     |      camión     |
# |   57   |     0      |    auto    |     0     |       auto      |
# |   58   |     0      |    auto    |     0     |       auto      |
# |   59   |     2      |   camión   |     2     |      camión     |
# |   60   |     1      |   barco    |     1     |      barco      |
# |   61   |     2      |   camión   |     2     |      camión     |
# |   62   |     0      |    auto    |     0     |       auto      |
# |   63   |     1      |   barco    |     1     |      barco      |
# |   64   |     1      |   barco    |     1     |      barco      |
# |   65   |     2      |   camión   |     2     |      camión     |
# |   66   |     2      |   camión   |     2     |      camión     |
# |   67   |     1      |   barco    |     1     |      barco      |
# |   68   |     0      |    auto    |     0     |       auto      |
# |   69   |     0      |    auto    |     0     |       auto      |
# |   70   |     0      |    auto    |     0     |       auto      |
# |   71   |     0      |    auto    |     0     |       auto      |
# |   72   |     0      |    auto    |     0     |       auto      |
# |   73   |     2      |   camión   |     2     |      camión     |
# |   74   |     2      |   camión   |     0     |       auto      |
# |   75   |     0      |    auto    |     0     |       auto      |
# |   76   |     1      |   barco    |     1     |      barco      |
# |   77   |     2      |   camión   |     2     |      camión     |
# |   78   |     2      |   camión   |     1     |      barco      |
# |   79   |     1      |   barco    |     1     |      barco      |
# |   80   |     1      |   barco    |     1     |      barco      |
# |   81   |     0      |    auto    |     0     |       auto      |
# |   82   |     2      |   camión   |     2     |      camión     |
# |   83   |     2      |   camión   |     2     |      camión     |
# |   84   |     1      |   barco    |     1     |      barco      |
# |   85   |     0      |    auto    |     0     |       auto      |
# |   86   |     2      |   camión   |     1     |      barco      |
# |   87   |     1      |   barco    |     1     |      barco      |
# |   88   |     0      |    auto    |     0     |       auto      |
# |   89   |     0      |    auto    |     0     |       auto      |
# |   90   |     0      |    auto    |     0     |       auto      |
# |   91   |     0      |    auto    |     2     |      camión     |
# |   92   |     0      |    auto    |     0     |       auto      |
# |   93   |     1      |   barco    |     1     |      barco      |
# |   94   |     0      |    auto    |     0     |       auto      |
# |   95   |     2      |   camión   |     2     |      camión     |
# |   96   |     2      |   camión   |     2     |      camión     |
# |   97   |     1      |   barco    |     1     |      barco      |
# |   98   |     2      |   camión   |     2     |      camión     |
# |   99   |     1      |   barco    |     1     |      barco      |
# +--------+------------+------------+-----------+-----------------+

# %%
from prettytable import PrettyTable

class_to_idx = {"auto": 0, "barco": 1, "camión": 2}

# Definir un diccionario que mapea los índices a los nombres de las clases
idx_to_class = {v: k for k, v in class_to_idx.items()}

# Encontrar las primeras 10 predicciones incorrectas
incorrect_predictions = []
for i in range(len(val_true_labels)):
    if val_true_labels[i] != val_predictions[i]:
        incorrect_predictions.append(i)
      ##  if len(incorrect_predictions) == 20:
        ##    break

# Crear una tabla para mostrar los resultados incorrectos
table = PrettyTable(["Índice", "True Value", "True Class", "Predicted", "Predicted Class"])

# Llenar la tabla con las primeras 10 predicciones incorrectas
for i in incorrect_predictions:
    table.add_row([i, val_true_labels[i], idx_to_class[val_true_labels[i]],
                   val_predictions[i], idx_to_class[val_predictions[i]]])

# Imprimir la tabla de las primeras 10 predicciones incorrectas
print("Predicciones Incorrectas para el Conjunto de Validación:")
print(table)
# Out:
# Predicciones Incorrectas para el Conjunto de Validación:
# +--------+------------+------------+-----------+-----------------+
# | Índice | True Value | True Class | Predicted | Predicted Class |
# +--------+------------+------------+-----------+-----------------+
# |   8    |     2      |   camión   |     1     |      barco      |
# |   17   |     2      |   camión   |     0     |       auto      |
# |   27   |     1      |   barco    |     2     |      camión     |
# |   40   |     1      |   barco    |     0     |       auto      |
# |   55   |     0      |    auto    |     1     |      barco      |
# |   74   |     2      |   camión   |     0     |       auto      |
# |   78   |     2      |   camión   |     1     |      barco      |
# |   86   |     2      |   camión   |     1     |      barco      |
# |   91   |     0      |    auto    |     2     |      camión     |
# |  110   |     2      |   camión   |     0     |       auto      |
# |  111   |     0      |    auto    |     1     |      barco      |
# |  132   |     2      |   camión   |     1     |      barco      |
# |  134   |     0      |    auto    |     1     |      barco      |
# |  169   |     2      |   camión   |     0     |       auto      |
# |  170   |     2      |   camión   |     0     |       auto      |
# |  177   |     2      |   camión   |     0     |       auto      |
# |  179   |     2      |   camión   |     0     |       auto      |
# |  198   |     1      |   barco    |     0     |       auto      |
# |  214   |     0      |    auto    |     2     |      camión     |
# |  217   |     2      |   camión   |     0     |       auto      |
# |  221   |     1      |   barco    |     2     |      camión     |
# |  233   |     2      |   camión   |     0     |       auto      |
# |  241   |     2      |   camión   |     1     |      barco      |
# |  253   |     0      |    auto    |     2     |      camión     |
# |  282   |     2      |   camión   |     0     |       auto      |
# |  293   |     2      |   camión   |     1     |      barco      |
# |  312   |     2      |   camión   |     0     |       auto      |
# |  336   |     2      |   camión   |     0     |       auto      |
# |  338   |     0      |    auto    |     2     |      camión     |
# |  347   |     2      |   camión   |     0     |       auto      |
# |  349   |     2      |   camión   |     0     |       auto      |
# |  366   |     0      |    auto    |     2     |      camión     |
# |  374   |     2      |   camión   |     1     |      barco      |
# |  378   |     2      |   camión   |     0     |       auto      |
# |  393   |     2      |   camión   |     0     |       auto      |
# |  408   |     2      |   camión   |     1     |      barco      |
# |  413   |     0      |    auto    |     1     |      barco      |
# |  422   |     0      |    auto    |     1     |      barco      |
# |  424   |     2      |   camión   |     0     |       auto      |
# |  435   |     2      |   camión   |     0     |       auto      |
# |  438   |     2      |   camión   |     0     |       auto      |
# |  451   |     0      |    auto    |     2     |      camión     |
# |  455   |     2      |   camión   |     0     |       auto      |
# |  462   |     0      |    auto    |     2     |      camión     |
# |  491   |     2      |   camión   |     0     |       auto      |
# |  520   |     0      |    auto    |     1     |      barco      |
# |  539   |     2      |   camión   |     0     |       auto      |
# |  549   |     0      |    auto    |     1     |      barco      |
# |  551   |     2      |   camión   |     0     |       auto      |
# |  560   |     2      |   camión   |     0     |       auto      |
# |  566   |     2      |   camión   |     1     |      barco      |
# |  573   |     2      |   camión   |     0     |       auto      |
# |  578   |     1      |   barco    |     2     |      camión     |
# |  586   |     2      |   camión   |     0     |       auto      |
# |  592   |     2      |   camión   |     0     |       auto      |
# |  602   |     2      |   camión   |     0     |       auto      |
# |  637   |     2      |   camión   |     0     |       auto      |
# |  644   |     2      |   camión   |     0     |       auto      |
# |  653   |     2      |   camión   |     0     |       auto      |
# |  667   |     2      |   camión   |     0     |       auto      |
# |  679   |     0      |    auto    |     1     |      barco      |
# |  681   |     2      |   camión   |     0     |       auto      |
# |  686   |     1      |   barco    |     0     |       auto      |
# |  687   |     0      |    auto    |     2     |      camión     |
# |  693   |     1      |   barco    |     0     |       auto      |
# |  702   |     2      |   camión   |     1     |      barco      |
# |  706   |     1      |   barco    |     0     |       auto      |
# |  707   |     0      |    auto    |     2     |      camión     |
# |  712   |     0      |    auto    |     2     |      camión     |
# |  723   |     0      |    auto    |     1     |      barco      |
# |  735   |     2      |   camión   |     1     |      barco      |
# |  750   |     2      |   camión   |     0     |       auto      |
# |  756   |     2      |   camión   |     0     |       auto      |
# |  757   |     2      |   camión   |     1     |      barco      |
# |  774   |     2      |   camión   |     0     |       auto      |
# |  778   |     1      |   barco    |     0     |       auto      |
# |  792   |     2      |   camión   |     0     |       auto      |
# |  793   |     2      |   camión   |     0     |       auto      |
# |  832   |     0      |    auto    |     1     |      barco      |
# |  834   |     1      |   barco    |     2     |      camión     |
# |  840   |     2      |   camión   |     0     |       auto      |
# |  841   |     0      |    auto    |     2     |      camión     |
# |  872   |     2      |   camión   |     1     |      barco      |
# |  875   |     2      |   camión   |     1     |      barco      |
# |  885   |     2      |   camión   |     1     |      barco      |
# |  886   |     2      |   camión   |     1     |      barco      |
# |  898   |     2      |   camión   |     0     |       auto      |
# |  911   |     2      |   camión   |     0     |       auto      |
# |  936   |     2      |   camión   |     0     |       auto      |
# |  944   |     2      |   camión   |     1     |      barco      |
# |  977   |     2      |   camión   |     0     |       auto      |
# |  989   |     2      |   camión   |     0     |       auto      |
# |  996   |     2      |   camión   |     1     |      barco      |
# |  1022  |     1      |   barco    |     2     |      camión     |
# |  1029  |     2      |   camión   |     0     |       auto      |
# |  1030  |     0      |    auto    |     2     |      camión     |
# |  1039  |     2      |   camión   |     1     |      barco      |
# |  1045  |     2      |   camión   |     1     |      barco      |
# |  1049  |     1      |   barco    |     2     |      camión     |
# |  1052  |     2      |   camión   |     1     |      barco      |
# |  1067  |     2      |   camión   |     1     |      barco      |
# |  1075  |     0      |    auto    |     1     |      barco      |
# |  1087  |     2      |   camión   |     0     |       auto      |
# |  1105  |     0      |    auto    |     1     |      barco      |
# |  1107  |     2      |   camión   |     1     |      barco      |
# |  1108  |     2      |   camión   |     0     |       auto      |
# |  1118  |     2      |   camión   |     0     |       auto      |
# |  1137  |     2      |   camión   |     0     |       auto      |
# |  1142  |     2      |   camión   |     0     |       auto      |
# |  1152  |     2      |   camión   |     0     |       auto      |
# |  1155  |     2      |   camión   |     0     |       auto      |
# |  1159  |     2      |   camión   |     0     |       auto      |
# |  1166  |     1      |   barco    |     0     |       auto      |
# |  1170  |     0      |    auto    |     2     |      camión     |
# |  1176  |     1      |   barco    |     2     |      camión     |
# |  1181  |     0      |    auto    |     2     |      camión     |
# |  1184  |     2      |   camión   |     0     |       auto      |
# |  1193  |     2      |   camión   |     1     |      barco      |
# |  1206  |     2      |   camión   |     0     |       auto      |
# |  1207  |     1      |   barco    |     0     |       auto      |
# |  1213  |     1      |   barco    |     0     |       auto      |
# |  1222  |     2      |   camión   |     1     |      barco      |
# |  1227  |     1      |   barco    |     0     |       auto      |
# |  1228  |     2      |   camión   |     0     |       auto      |
# |  1246  |     2      |   camión   |     0     |       auto      |
# |  1260  |     2      |   camión   |     1     |      barco      |
# |  1266  |     1      |   barco    |     2     |      camión     |
# |  1281  |     2      |   camión   |     1     |      barco      |
# |  1288  |     2      |   camión   |     0     |       auto      |
# |  1298  |     0      |    auto    |     2     |      camión     |
# |  1306  |     2      |   camión   |     0     |       auto      |
# |  1313  |     2      |   camión   |     1     |      barco      |
# |  1318  |     2      |   camión   |     1     |      barco      |
# |  1338  |     2      |   camión   |     0     |       auto      |
# |  1340  |     2      |   camión   |     0     |       auto      |
# |  1382  |     0      |    auto    |     2     |      camión     |
# |  1384  |     2      |   camión   |     1     |      barco      |
# |  1446  |     2      |   camión   |     1     |      barco      |
# |  1454  |     0      |    auto    |     1     |      barco      |
# |  1458  |     1      |   barco    |     2     |      camión     |
# |  1462  |     2      |   camión   |     0     |       auto      |
# |  1464  |     0      |    auto    |     1     |      barco      |
# |  1466  |     0      |    auto    |     1     |      barco      |
# |  1474  |     2      |   camión   |     0     |       auto      |
# |  1478  |     0      |    auto    |     1     |      barco      |
# |  1493  |     2      |   camión   |     0     |       auto      |
# |  1502  |     1      |   barco    |     2     |      camión     |
# |  1514  |     2      |   camión   |     0     |       auto      |
# |  1520  |     2      |   camión   |     0     |       auto      |
# |  1532  |     2      |   camión   |     0     |       auto      |
# |  1552  |     0      |    auto    |     1     |      barco      |
# |  1569  |     2      |   camión   |     1     |      barco      |
# |  1579  |     2      |   camión   |     0     |       auto      |
# |  1580  |     2      |   camión   |     0     |       auto      |
# |  1583  |     2      |   camión   |     0     |       auto      |
# |  1605  |     1      |   barco    |     0     |       auto      |
# |  1607  |     1      |   barco    |     0     |       auto      |
# |  1608  |     2      |   camión   |     0     |       auto      |
# |  1617  |     0      |    auto    |     2     |      camión     |
# |  1637  |     1      |   barco    |     0     |       auto      |
# |  1638  |     2      |   camión   |     0     |       auto      |
# |  1644  |     2      |   camión   |     1     |      barco      |
# |  1646  |     2      |   camión   |     0     |       auto      |
# |  1657  |     1      |   barco    |     0     |       auto      |
# |  1670  |     0      |    auto    |     2     |      camión     |
# |  1674  |     1      |   barco    |     0     |       auto      |
# |  1684  |     2      |   camión   |     0     |       auto      |
# |  1690  |     2      |   camión   |     1     |      barco      |
# |  1694  |     1      |   barco    |     0     |       auto      |
# |  1702  |     2      |   camión   |     1     |      barco      |
# |  1713  |     2      |   camión   |     0     |       auto      |
# |  1725  |     1      |   barco    |     0     |       auto      |
# |  1730  |     1      |   barco    |     2     |      camión     |
# |  1746  |     2      |   camión   |     0     |       auto      |
# |  1762  |     0      |    auto    |     1     |      barco      |
# |  1763  |     2      |   camión   |     0     |       auto      |
# |  1773  |     2      |   camión   |     0     |       auto      |
# |  1778  |     0      |    auto    |     2     |      camión     |
# |  1783  |     0      |    auto    |     1     |      barco      |
# |  1794  |     2      |   camión   |     0     |       auto      |
# |  1810  |     2      |   camión   |     0     |       auto      |
# |  1820  |     0      |    auto    |     1     |      barco      |
# |  1825  |     2      |   camión   |     0     |       auto      |
# |  1831  |     2      |   camión   |     0     |       auto      |
# |  1842  |     2      |   camión   |     0     |       auto      |
# |  1873  |     2      |   camión   |     0     |       auto      |
# |  1875  |     0      |    auto    |     1     |      barco      |
# |  1876  |     0      |    auto    |     2     |      camión     |
# |  1883  |     2      |   camión   |     0     |       auto      |
# |  1896  |     2      |   camión   |     0     |       auto      |
# |  1899  |     0      |    auto    |     2     |      camión     |
# |  1907  |     0      |    auto    |     1     |      barco      |
# |  1912  |     0      |    auto    |     1     |      barco      |
# |  1929  |     2      |   camión   |     0     |       auto      |
# |  1947  |     0      |    auto    |     2     |      camión     |
# |  1998  |     2      |   camión   |     1     |      barco      |
# |  2013  |     2      |   camión   |     0     |       auto      |
# |  2029  |     2      |   camión   |     0     |       auto      |
# |  2044  |     2      |   camión   |     0     |       auto      |
# |  2053  |     2      |   camión   |     0     |       auto      |
# |  2064  |     2      |   camión   |     0     |       auto      |
# |  2065  |     2      |   camión   |     0     |       auto      |
# |  2070  |     2      |   camión   |     0     |       auto      |
# |  2101  |     2      |   camión   |     0     |       auto      |
# |  2115  |     1      |   barco    |     2     |      camión     |
# |  2189  |     0      |    auto    |     1     |      barco      |
# |  2193  |     2      |   camión   |     0     |       auto      |
# |  2201  |     2      |   camión   |     1     |      barco      |
# |  2214  |     1      |   barco    |     0     |       auto      |
# |  2215  |     0      |    auto    |     2     |      camión     |
# |  2220  |     2      |   camión   |     0     |       auto      |
# |  2222  |     2      |   camión   |     0     |       auto      |
# |  2235  |     0      |    auto    |     2     |      camión     |
# |  2254  |     1      |   barco    |     0     |       auto      |
# |  2258  |     0      |    auto    |     2     |      camión     |
# |  2264  |     2      |   camión   |     0     |       auto      |
# |  2268  |     0      |    auto    |     1     |      barco      |
# |  2275  |     2      |   camión   |     1     |      barco      |
# |  2277  |     1      |   barco    |     0     |       auto      |
# |  2285  |     1      |   barco    |     2     |      camión     |
# |  2310  |     2      |   camión   |     1     |      barco      |
# |  2314  |     1      |   barco    |     0     |       auto      |
# |  2351  |     1      |   barco    |     0     |       auto      |
# |  2371  |     2      |   camión   |     0     |       auto      |
# |  2380  |     2      |   camión   |     0     |       auto      |
# |  2383  |     2      |   camión   |     0     |       auto      |
# |  2391  |     2      |   camión   |     0     |       auto      |
# |  2405  |     1      |   barco    |     2     |      camión     |
# |  2408  |     2      |   camión   |     0     |       auto      |
# |  2426  |     2      |   camión   |     1     |      barco      |
# |  2434  |     0      |    auto    |     1     |      barco      |
# |  2440  |     0      |    auto    |     2     |      camión     |
# |  2451  |     2      |   camión   |     0     |       auto      |
# |  2456  |     2      |   camión   |     0     |       auto      |
# |  2475  |     0      |    auto    |     2     |      camión     |
# |  2482  |     0      |    auto    |     2     |      camión     |
# |  2484  |     2      |   camión   |     0     |       auto      |
# |  2489  |     2      |   camión   |     1     |      barco      |
# |  2512  |     2      |   camión   |     0     |       auto      |
# |  2565  |     1      |   barco    |     0     |       auto      |
# |  2569  |     0      |    auto    |     1     |      barco      |
# |  2594  |     1      |   barco    |     0     |       auto      |
# |  2596  |     0      |    auto    |     1     |      barco      |
# |  2602  |     2      |   camión   |     0     |       auto      |
# |  2604  |     0      |    auto    |     1     |      barco      |
# |  2611  |     1      |   barco    |     0     |       auto      |
# |  2616  |     0      |    auto    |     1     |      barco      |
# |  2628  |     2      |   camión   |     1     |      barco      |
# |  2638  |     2      |   camión   |     0     |       auto      |
# |  2647  |     2      |   camión   |     1     |      barco      |
# |  2652  |     2      |   camión   |     0     |       auto      |
# |  2675  |     2      |   camión   |     0     |       auto      |
# |  2678  |     1      |   barco    |     0     |       auto      |
# |  2679  |     2      |   camión   |     0     |       auto      |
# |  2683  |     0      |    auto    |     2     |      camión     |
# |  2703  |     2      |   camión   |     1     |      barco      |
# |  2713  |     2      |   camión   |     0     |       auto      |
# |  2714  |     2      |   camión   |     1     |      barco      |
# |  2724  |     2      |   camión   |     0     |       auto      |
# |  2737  |     2      |   camión   |     0     |       auto      |
# |  2753  |     2      |   camión   |     0     |       auto      |
# |  2772  |     0      |    auto    |     1     |      barco      |
# |  2792  |     2      |   camión   |     0     |       auto      |
# |  2798  |     0      |    auto    |     2     |      camión     |
# |  2826  |     0      |    auto    |     2     |      camión     |
# |  2830  |     2      |   camión   |     0     |       auto      |
# |  2835  |     0      |    auto    |     2     |      camión     |
# |  2848  |     0      |    auto    |     1     |      barco      |
# |  2856  |     2      |   camión   |     1     |      barco      |
# |  2860  |     2      |   camión   |     0     |       auto      |
# |  2871  |     0      |    auto    |     1     |      barco      |
# |  2876  |     2      |   camión   |     0     |       auto      |
# |  2895  |     2      |   camión   |     1     |      barco      |
# |  2906  |     2      |   camión   |     0     |       auto      |
# |  2911  |     2      |   camión   |     0     |       auto      |
# |  2928  |     2      |   camión   |     0     |       auto      |
# |  2937  |     2      |   camión   |     0     |       auto      |
# |  2948  |     2      |   camión   |     1     |      barco      |
# |  2955  |     2      |   camión   |     0     |       auto      |
# |  2979  |     0      |    auto    |     2     |      camión     |
# |  2989  |     0      |    auto    |     1     |      barco      |
# |  2998  |     1      |   barco    |     0     |       auto      |
# |  2999  |     0      |    auto    |     2     |      camión     |
# |  3011  |     1      |   barco    |     2     |      camión     |
# |  3014  |     0      |    auto    |     1     |      barco      |
# |  3017  |     2      |   camión   |     0     |       auto      |
# |  3042  |     2      |   camión   |     0     |       auto      |
# |  3043  |     2      |   camión   |     0     |       auto      |
# |  3068  |     2      |   camión   |     0     |       auto      |
# |  3079  |     1      |   barco    |     0     |       auto      |
# |  3084  |     2      |   camión   |     0     |       auto      |
# |  3086  |     2      |   camión   |     1     |      barco      |
# |  3092  |     1      |   barco    |     0     |       auto      |
# |  3100  |     1      |   barco    |     2     |      camión     |
# |  3108  |     1      |   barco    |     0     |       auto      |
# |  3109  |     0      |    auto    |     2     |      camión     |
# |  3123  |     2      |   camión   |     0     |       auto      |
# |  3125  |     0      |    auto    |     1     |      barco      |
# |  3131  |     0      |    auto    |     2     |      camión     |
# |  3146  |     1      |   barco    |     0     |       auto      |
# |  3157  |     2      |   camión   |     1     |      barco      |
# |  3161  |     1      |   barco    |     2     |      camión     |
# |  3169  |     2      |   camión   |     0     |       auto      |
# |  3177  |     2      |   camión   |     0     |       auto      |
# |  3200  |     2      |   camión   |     0     |       auto      |
# |  3223  |     2      |   camión   |     0     |       auto      |
# |  3232  |     2      |   camión   |     1     |      barco      |
# |  3233  |     1      |   barco    |     0     |       auto      |
# |  3255  |     1      |   barco    |     0     |       auto      |
# |  3264  |     2      |   camión   |     0     |       auto      |
# |  3269  |     2      |   camión   |     0     |       auto      |
# |  3296  |     1      |   barco    |     0     |       auto      |
# |  3329  |     2      |   camión   |     0     |       auto      |
# |  3332  |     1      |   barco    |     2     |      camión     |
# |  3349  |     2      |   camión   |     0     |       auto      |
# |  3364  |     1      |   barco    |     2     |      camión     |
# |  3387  |     2      |   camión   |     0     |       auto      |
# |  3404  |     0      |    auto    |     1     |      barco      |
# |  3420  |     2      |   camión   |     0     |       auto      |
# |  3426  |     2      |   camión   |     1     |      barco      |
# |  3447  |     0      |    auto    |     1     |      barco      |
# |  3466  |     2      |   camión   |     0     |       auto      |
# |  3477  |     2      |   camión   |     1     |      barco      |
# |  3484  |     0      |    auto    |     2     |      camión     |
# |  3486  |     0      |    auto    |     1     |      barco      |
# |  3489  |     0      |    auto    |     2     |      camión     |
# |  3497  |     2      |   camión   |     0     |       auto      |
# |  3544  |     0      |    auto    |     2     |      camión     |
# |  3546  |     0      |    auto    |     1     |      barco      |
# |  3548  |     2      |   camión   |     0     |       auto      |
# |  3555  |     2      |   camión   |     0     |       auto      |
# |  3560  |     2      |   camión   |     0     |       auto      |
# |  3595  |     0      |    auto    |     2     |      camión     |
# |  3599  |     1      |   barco    |     2     |      camión     |
# |  3609  |     1      |   barco    |     0     |       auto      |
# |  3628  |     1      |   barco    |     0     |       auto      |
# |  3630  |     2      |   camión   |     0     |       auto      |
# |  3639  |     1      |   barco    |     2     |      camión     |
# |  3644  |     1      |   barco    |     0     |       auto      |
# |  3668  |     0      |    auto    |     1     |      barco      |
# |  3673  |     2      |   camión   |     0     |       auto      |
# |  3676  |     0      |    auto    |     2     |      camión     |
# |  3692  |     2      |   camión   |     0     |       auto      |
# |  3701  |     2      |   camión   |     0     |       auto      |
# |  3704  |     2      |   camión   |     0     |       auto      |
# |  3711  |     2      |   camión   |     0     |       auto      |
# |  3727  |     2      |   camión   |     1     |      barco      |
# +--------+------------+------------+-----------+-----------------+

# %%
import pandas as pd
from tabulate import tabulate

# Matrices de confusión obtenidas anteriormente
confusion_train = train_confusion_matrix
confusion_valid = val_confusion_matrix

# Nombres de las clases
class_names = ['auto', 'barco', 'camión']

# Función para calcular el porcentaje
def calculate_percentage(correct, incorrect):
    total = correct + incorrect
    if total == 0:
        return 0.0
    return (correct / total) * 100.0

# Calcular la cantidad de predicciones correctas e incorrectas por clase en los tres conjuntos
correct_train_per_class = [confusion_train[i, i] for i in range(len(class_names))]
incorrect_train_per_class = [sum(confusion_train[i, :]) - confusion_train[i, i] for i in range(len(class_names))]

correct_valid_per_class = [confusion_valid[i, i] for i in range(len(class_names))]
incorrect_valid_per_class = [sum(confusion_valid[i, :]) - confusion_valid[i, i] for i in range(len(class_names))]

# Crear listas de listas para las tablas de los tres conjuntos
train_table_data = []
valid_table_data = []

for class_name, correct_count, incorrect_count in zip(class_names, correct_train_per_class, incorrect_train_per_class):
    train_percentage = calculate_percentage(correct_count, incorrect_count)
    train_table_data.append([class_name, correct_count, incorrect_count, f"{train_percentage:.2f}%"])

for class_name, correct_count, incorrect_count in zip(class_names, correct_valid_per_class, incorrect_valid_per_class):
    valid_percentage = calculate_percentage(correct_count, incorrect_count)
    valid_table_data.append([class_name, correct_count, incorrect_count, f"{valid_percentage:.2f}%"])

# Agregar una fila con la suma de cada columna en las tablas de predicciones
train_table_data.append(['Total', sum(correct_train_per_class), sum(incorrect_train_per_class), ''])
valid_table_data.append(['Total', sum(correct_valid_per_class), sum(incorrect_valid_per_class), ''])

# Calcular los porcentajes de aciertos en los totales
total_aciertos_train = calculate_percentage(sum(correct_train_per_class), sum(incorrect_train_per_class))
total_aciertos_valid = calculate_percentage(sum(correct_valid_per_class), sum(incorrect_valid_per_class))

# Agregar los porcentajes de aciertos en la fila de Totales de las tablas de predicciones
train_table_data[-1][-1] = f"{total_aciertos_train:.2f}%"
valid_table_data[-1][-1] = f"{total_aciertos_valid:.2f}%"

# Imprimir las tablas formateadas para los dos conjuntos
table_headers = ["Clase", "Predicciones Correctas", "Predicciones Incorrectas", "Porcentaje de Aciertos"]

def print_table(title, data):
    print(title)
    table = tabulate(data, headers=table_headers, tablefmt='pretty', numalign='center', stralign='center', colalign=("center", "center", "center", "center"))
    print(table)

print_table("Tabla de Predicciones (Entrenamiento):", train_table_data)
print_table("Tabla de Predicciones (Validación):", valid_table_data)
# Out:
# Tabla de Predicciones (Entrenamiento):
# +--------+------------------------+--------------------------+------------------------+
# | Clase  | Predicciones Correctas | Predicciones Incorrectas | Porcentaje de Aciertos |
# +--------+------------------------+--------------------------+------------------------+
# |  auto  |          3670          |            6             |         99.84%         |
# | barco  |          3814          |            17            |         99.56%         |
# | camión |          3630          |           113            |         96.98%         |
# | Total  |         11114          |           136            |         98.79%         |
# +--------+------------------------+--------------------------+------------------------+
# Tabla de Predicciones (Validación):
# +--------+------------------------+--------------------------+------------------------+
# | Clase  | Predicciones Correctas | Predicciones Incorrectas | Porcentaje de Aciertos |
# +--------+------------------------+--------------------------+------------------------+
# |  auto  |          1242          |            82            |         93.81%         |
# | barco  |          1111          |            58            |         95.04%         |
# | camión |          1050          |           207            |         83.53%         |
# | Total  |          3403          |           347            |         90.75%         |
# +--------+------------------------+--------------------------+------------------------+

# %% [markdown]
# ### Gráficos

# %%
import matplotlib.pyplot as plt
# Visualizar las matrices de confusión
def plot_confusion_matrix(cm, classes, title):
    plt.figure(figsize=(12, 6))

    plt.subplot(1, 2, 1)
    plt.imshow(cm[0], interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Entrenamiento')
    plt.xticks(np.arange(len(classes)), classes, rotation=45)
    plt.yticks(np.arange(len(classes)), classes)
    for i in range(len(classes)):
        for j in range(len(classes)):
            plt.text(j, i, str(cm[0][i][j]), ha='center', va='center', color='black')

    plt.subplot(1, 2, 2)
    plt.imshow(cm[1], interpolation='nearest', cmap=plt.cm.Blues)
    plt.title('Validación')
    plt.xticks(np.arange(len(classes)), classes, rotation=45)
    plt.yticks(np.arange(len(classes)), classes)
    for i in range(len(classes)):
        for j in range(len(classes)):
            plt.text(j, i, str(cm[1][i][j]), ha='center', va='center', color='black')

    plt.tight_layout()
    plt.suptitle(title)
    plt.show()

# Clases en orden
class_names = classes_to_keep

# Graficar matrices de confusión
plot_confusion_matrix([train_confusion_matrix, val_confusion_matrix], classes=class_names, title='')

# %%
import matplotlib.pyplot as plt

# Crear un arreglo de épocas para el eje x
epochs = list(range(1, len(train_loss_history) + 1))

# Graficar la pérdida de entrenamiento y validación en el mismo gráfico
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss_history, label='Train Loss')
plt.plot(epochs, val_loss_history, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Train and Validation Loss')
plt.legend()

# Graficar la precisión de entrenamiento y validación en el mismo gráfico
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy_history, label='Train Accuracy')
plt.plot(epochs, val_accuracy_history, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy (%)')
plt.title('Train and Validation Accuracy')
plt.legend()

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Función para obtener las probabilidades en el conjunto de validación
def get_probabilities(net, dataloader):
    all_probabilities = []
    net.eval()
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data
            outputs = net(inputs)
            probabilities = torch.softmax(outputs, dim=1)
            all_probabilities.extend(probabilities.cpu().numpy())
    return np.array(all_probabilities)

# Obtener las probabilidades en el conjunto de validación
val_probabilities = get_probabilities(net, valloader)

# Distribución de probabilidades
fig = plt.figure(figsize=(9, 6))

# Definir los bins para el histograma
bins = np.linspace(0, 1, 50)

# Histograma de probabilidades en casos correctos
probs_correct = []
for i, (true_label, probabilities) in enumerate(zip(val_true_labels, val_probabilities)):
    if true_label == np.argmax(probabilities):
        probs_correct.append(probabilities[true_label])
probs_correct = np.array(probs_correct)
plt.hist(probs_correct, bins=bins, histtype='step', label='Correcto', density=True, log=True)

# Histograma de probabilidades en casos incorrectos
probs_incorrect = []
for i, (true_label, probabilities) in enumerate(zip(val_true_labels, val_probabilities)):
    if true_label != np.argmax(probabilities):
        probs_incorrect.append(probabilities[true_label])
probs_incorrect = np.array(probs_incorrect)
plt.hist(probs_incorrect, bins=bins, histtype='step', label='Incorrecto', density=True)

# Etiquetas y marcas
plt.xlabel('Probabilidad', size=14)
plt.gca().tick_params(axis='both', which='major', labelsize=14)

plt.legend(loc=2)
plt.show()

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# Función para mostrar las imágenes en dos filas con etiquetas y predicciones del modelo
def show_images_in_two_rows(images, true_labels, predicted_labels):
    fig, axs = plt.subplots(2, 10, figsize=(20, 5))
    for i in range(20):  # Mostrar solo las primeras 20 imágenes
        row = i // 10
        col = i % 10
        img = images[i] / 2 + 0.5  # Desnormalizar
        npimg = img.numpy()
        axs[row, col].imshow(np.transpose(npimg, (1, 2, 0)))
        title = f'True: {idx_to_class[true_labels[i].item()]}\nPredicted: {idx_to_class[predicted_labels[i].item()]}'
        axs[row, col].set_title(title)
        axs[row, col].axis('off')
    plt.show()

# Obtener las imágenes y etiquetas correspondientes a las predicciones incorrectas
incorrect_images = [valset[i][0] for i in incorrect_predictions[:20]]  # Tomar solo las primeras 20 imágenes
true_labels = [torch.tensor(valset[i][1]) for i in incorrect_predictions[:20]]
predicted_labels = [torch.tensor(val_predictions[i]) for i in incorrect_predictions[:20]]

# Mostrar las imágenes en dos filas con etiquetas y predicciones del modelo
print("Imágenes correspondientes a las Predicciones Incorrectas:")
show_images_in_two_rows(incorrect_images, true_labels, predicted_labels)
# Out:
# Imágenes correspondientes a las Predicciones Incorrectas:
